# %%
import symbol as s
import pandas as pd
import numpy as np
import os
from datetime import datetime
import seaborn as sns
sns.set_style("whitegrid")

# %matplotlib inline

# %%
symbol = s.Symbol()

# %%
ret = symbol.get_symbol_returns()

# %%
ncount = symbol.symbol_returns_null_count()

# %%
def consecutive_nulls(series):
    symbol = series.name
    series.name = 'symbol'
    null_series = pd.DataFrame(series)
    null_series['null_count'] = 0
    some series = 0 if x.isnull() else 
    return null_count
# %timeit returns_null_count = ret.apply(consecutive_nulls)

# %%
ncount

# %%
# %timeit s.null_count(ret)

# %%
ret.columns[s.null_count(ret) <= 0]

# %%
sma = {
    'metals_and_mining':'metals',
    'technology': 'it',
    'consumer_goods': 'fmcg',
    'pharma_and_healthcare':'pharma',
    'chemicals_and_fertilizers': 'chem', 
    'oil_and_gas':'energy',
    'industrial_equipment':'industrial_goods',
    'cement':'cement',
    'engineering_and_capital_goods':'engineering',
    'trading_and_exports':'trade', 
    'power':'energy', 
    'travel_and_hotels':'tourism', 
    'telecom':'telecom',
    'construction':'construction', 
    'industrial_cables': 'industrial_goods', 
    'banking_and_finance': 'bfsi',
    'agriculture_and_food_processing': 'agri', 
    'auto': 'auto', 
    'packaging':'misc',
    'miscellaneous':'misc', 
    'education':'edu', 
    'plastics':'misc', 
    'media':'media',
    'consumer_durables':'fmcg', 
    'sugar':'sugar', 
    'paper_and_stationery':'paper'
}

# %%
pd.Series(sma).to_dict()

# %%
s.clean_file('constants.h5')

# %%
smeta = symbol.get_symbol_meta()
smeta.industry.replace(pd.Series(sma).to_dict())

# %%
s.get_store_keys('index_data.h5')
# Out:
# ['/index_data_daily', '/index_returns_daily']

# %%
idata = pd.read_hdf('index_data.h5', 'index_data_daily')

# %%
idata.to_hdf('index_data.h5', 'index_data_daily')

# %%
idata
# Out:
#             nifty_50  nifty_next_50  nifty_midcap_50  nifty_midcap_150  \
# 1995-01-02   1182.14            NaN              NaN               NaN
# 1995-01-03   1176.82            NaN              NaN               NaN
# 1995-01-04   1163.72            NaN              NaN               NaN
# 1995-01-05   1150.02            NaN              NaN               NaN
# 1995-01-06   1130.36            NaN              NaN               NaN
# 1995-01-09   1112.10            NaN              NaN               NaN
# 1995-01-10   1079.20            NaN              NaN               NaN
# 1995-01-11   1067.58            NaN              NaN               NaN
# 1995-01-12   1066.19            NaN              NaN               NaN
# 1995-01-13   1074.43            NaN              NaN               NaN
# 1995-01-16   1087.80            NaN              NaN               NaN
# 1995-01-17   1084.08            NaN              NaN               NaN
# ...
