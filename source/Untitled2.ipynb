# %%
import pandas as pd

# %%
pd.read_hdf('constants.h5', 'index_meta')
# Out:
#                                                               name  \
# index_code
# nifty_50                                                  Nifty 50
# nifty_next_50                                        Nifty Next 50
# nifty_midcap_50                                    NIFTY MIDCAP 50
# nifty_free_float_midcap_100            Nifty Free Float MidCap 100
# nifty_free_float_smallcap_100        Nifty Free Float SmallCap 100
# nifty_midcap_150                                  Nifty MidCap 150
# nifty_smallcap_250                              Nifty SmallCap 250
# nifty_free_float_midsmallcap_400  Nifty Free Float MidSmallCap 400
# nifty_500                                                Nifty 500
# nifty_alpha_50                                      Nifty Alpha 50
# nifty_high_beta_50                              Nifty High Beta 50
# nifty_div_opps_50                                Nifty Div Opps 50
# nifty_growth_sectors_15                    Nifty Growth Sectors 15
# ...
