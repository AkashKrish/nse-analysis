# %%
using PyCall, Pandas, DataFrames
# Out:
# WARNING: using Pandas.melt in module Main conflicts with an existing identifier.
# WARNING: using Pandas.cut in module Main conflicts with an existing identifier.
# WARNING: using Pandas.unstack in module Main conflicts with an existing identifier.
# WARNING: using Pandas.describe in module Main conflicts with an existing identifier.
# WARNING: using Pandas.dropna in module Main conflicts with an existing identifier.
# WARNING: using Pandas.sample in module Main conflicts with an existing identifier.
# WARNING: using Pandas.DataFrame in module Main conflicts with an existing identifier.
# WARNING: using Pandas.stack in module Main conflicts with an existing identifier.
# WARNING: using Pandas.rename in module Main conflicts with an existing identifier.
# WARNING: using Pandas.aggregate in module Main conflicts with an existing identifier.
# WARNING: using Pandas.tail in module Main conflicts with an existing identifier.
# ...

# %%
@time begin
    readtable("symbol_hist_data.csv")
end
@time begin
    read_csv("symbol_hist_data.csv")
end
# Out:
#  73.017184 seconds (135.65 M allocations: 4.729 GB, 8.65% gc time)
#  18.054099 seconds (40 allocations: 1.391 KB)
#          Unnamed: 0     symbol        date  prev_close    open    high  \
# 0                 0  20microns  2008-10-06       55.00   80.00   80.00
# 1                 1  20microns  2008-10-07       33.65   32.00   38.00
# 2                 2  20microns  2008-10-08       30.10   28.00   29.20
# 3                 3  20microns  2008-10-10       26.50   24.90   24.90
# 4                 4  20microns  2008-10-13       23.20   24.30   26.60
# 5                 5  20microns  2008-10-14       24.65   25.65   26.00
# 6                 6  20microns  2008-10-15       22.15   21.30   25.55
# 7                 7  20microns  2008-10-16       24.35   22.05   29.25
# 8                 8  20microns  2008-10-17       27.40   28.05   28.70
# 9                 9  20microns  2008-10-20       22.05   22.50   23.25
# 10               10  20microns  2008-10-21       21.75   22.80   22.95
# ...

# %%
@pyimport pandas
@pyimport PyTables
# Out:
# PyError (:PyImport_ImportModule) <type 'exceptions.ImportError'>
# ImportError('No module named PyTables',)
#
#
#  in pyerr_check at C:\Users\Akash\.julia\v0.5\PyCall\src\exception.jl:56 [inlined]
#  in pyerr_check at C:\Users\Akash\.julia\v0.5\PyCall\src\exception.jl:61 [inlined]
#  in macro expansion at C:\Users\Akash\.julia\v0.5\PyCall\src\exception.jl:81 [inlined]
#  in pyimport(::String) at C:\Users\Akash\.julia\v0.5\PyCall\src\PyCall.jl:387

# %%
# Out:
# PyError (:PyObject_Call) <type 'exceptions.ImportError'>
# ImportError('HDFStore requires PyTables, "No module named tables" problem importing',)
#   File "C:\Users\Akash\.julia\v0.5\Conda\deps\usr\lib\site-packages\pandas\io\pytables.py", line 330, in read_hdf
#     store = HDFStore(path_or_buf, **kwargs)
#   File "C:\Users\Akash\.julia\v0.5\Conda\deps\usr\lib\site-packages\pandas\io\pytables.py", line 433, in __init__
#     'importing'.format(ex=str(ex)))
#
#
#  in pyerr_check at C:\Users\Akash\.julia\v0.5\PyCall\src\exception.jl:56 [inlined]
#  in pyerr_check at C:\Users\Akash\.julia\v0.5\PyCall\src\exception.jl:61 [inlined]
#  in macro expansion at C:\Users\Akash\.julia\v0.5\PyCall\src\exception.jl:81 [inlined]
#  in #_pycall#66(::Array{Any,1}, ::Function, ::PyCall.PyObject, ::String, ::Vararg{String,N}) at C:\Users\Akash\.julia\v0.5\PyCall\src\PyCall.jl:546
#  in _pycall(::PyCall.PyObject, ::String, ::Vararg{String,N}) at C:\Users\Akash\.julia\v0.5\PyCall\src\PyCall.jl:534
# ...
