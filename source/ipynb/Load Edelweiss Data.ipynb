# %%
import json
import requests

import pandas as pd
import numpy as np

from symbol import Symbol
from edelweiss import Edelweiss

# %%
edel = Edelweiss()

# %%
edel.load_symbol_codes()
# Out:
# Loaded Successfully for 20microns
# Loaded Successfully for 3iinfotech
# Loaded Successfully for 3mindia
# Loaded Successfully for 63moons
# Loaded Successfully for 8kmiles
# Loaded Successfully for a2zinfra
# Loaded Successfully for aartidrugs
# Loaded Successfully for aartiind
# Loaded Successfully for aarveeden
# Loaded Successfully for aban
# Loaded Successfully for abb
# Loaded Successfully for abbotindia
# Loaded Successfully for abfrl
# Loaded Successfully for abirlanuvo
# Loaded Successfully for acc
# Loaded Successfully for accelya
# Loaded Successfully for ace
# Loaded Successfully for adanient
# Loaded Successfully for adaniports
# Loaded Successfully for adanipower
# Loaded Successfully for adanitrans
# Loaded Successfully for adffoods
# Loaded Successfully for adhunik
# Loaded Successfully for adhunikind
# Loaded Successfully for adlabs
# Loaded Successfully for adorweld
# Loaded Successfully for advanihotr
# Loaded Successfully for advenzymes
# ...
