# %%
import requests
import json
from datetime import datetime
from bs4 import BeautifulSoup
import pandas as pd
from edelweiss import Edelweiss
from symbol import Symbol
from iifl import IIFL
# %matplotlib inline

# %%
session = requests.session()
symbol = Symbol()
smeta = symbol.symbol_meta.copy()
iifl = IIFL()
codes = iifl.get_code_data()

# %%
holding_url = 'http://www.indiainfoline.com/live-market/company/get-share-holding-data'
actions_url = 'http://www.indiainfoline.com/live-market/company/get-corporat-action-data'
historical_url = 'http://www.indiainfoline.com/live-market/company/ajax-get-historical-data'
bs_url = 'http://www.indiainfoline.com/live-market/company/balance-sheet-data'
request_headers = {
    'Accept': '*/*',
    'Accept-Encoding': 'gzip, deflate',
    'Accept-Language': 'en-US,en;q=0.8',
    'Connection': 'keep-alive',
    'Content-Length': '86',
    'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
    'DNT':'1',
    'Host': 'www.indiainfoline.com',
    'Origin': 'http://www.indiainfoline.com',
    'Referer': 'http://www.indiainfoline.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36',
    "X-Requested-With": 'XMLHttpRequest'
}

# %%
url = 'http://www.indiainfoline.com/company/wipro-ltd/share-holding/'
# session.get()
search_url = 'http://www.indiainfoline.com/personal-finance/request-handler/get-search-names'
search_headers = {
    'Accept': '*/*',
    'Accept-Encoding': 'gzip, deflate',
    'Accept-Language': 'en-US,en;q=0.8',
    'Connection': 'keep-alive',
    'Content-Length': '86',
    'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
    'DNT':'1',
    'Host': 'www.indiainfoline.com',
    'Origin': 'http://www.indiainfoline.com',
    'Referer': 'http://www.indiainfoline.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36',
    "X-Requested-With": 'XMLHttpRequest'
}

# %%
response = session.get('http://www.indiainfoline.com/company/wipro-ltd-key-ratios/financials/614', headers=request_headers)

# %%
data = {
    'cocode': '2806',
    'activeExchange': 'nse'
}
resp = session.post(bs_url, headers=request_headers, data=data)

# %%
soup = BeautifulSoup(resp.text, 'html.parser')
soup_text = str(soup)#.replace('%', '')

# %%
soup
# Out:
# <div class="light_gray_bg col-lg-12 p10">
# <div class="row ">
# <div class="col-lg-6 col-md-6 col-sm-6 col-xs-12 balConStanChecker">
# <dl>
# <dt class="fs12e txt_normal ">Switch to </dt>
# <dd class=" mt5">
# <div class="pull-left">Consolidated</div>
# <div class="pull-left plugin plr10 mt3 mb0">
# <input class="plug plug_hidden balancesheetConsoStandSwitch" id="balancesheetConsoStandSwitch" type="checkbox"/>
# <label class="plug_btn" for="balancesheetConsoStandSwitch"></label>
# </div>
# <div class="pull-left">Standalone</div>
# <div class="clearfix"></div>
# </dd>
# </dl>
# </div>
# <!--<div class="lblstandAloneBankRatio headlines text-left txt_italic"> * Consolidated Values</div>-->
# </div>
# </div>
# <section class=" sub_block row ">
# <article class="col-lg-4 col-md-4 col-sm-7 col-xs-12 mt10 balancesheetConsolidateTabular" style="display:block">
# <!--<div class="col-lg-12 col-md-12 col-sm-12 col-xs-12">
# ...

# %%
shareholding_data.drop([0, 4, 9])
# Out:
#                       Dec-2016 Sep-2016 Jun-2016 Mar-2016
# 0             Foreign     0.00     0.00     0.00     0.00
# 1              Indian    12.75    12.75    12.75    12.75
# 2      Total Promoter    12.75    12.75    12.75    12.75
# 3        Institutions    57.89    57.57    57.71    57.69
# 4    Non-Institutions    28.87    29.19    29.05    29.07
# 5  Total Non-Promoter    86.76    86.76    86.76    86.76
# 6           Custodian     0.49     0.49     0.49     0.49
